# %% [markdown]
# 4.take n number n times

# %%
n = int(input("Enter n: "))



for i in range(n):
    value = input("Enter a value: ")
    print(value)
# Out:
# Enter n:  4
# Enter a value:  1
# 1
# Enter a value:  2
# 2
# Enter a value:  3
# 3
# Enter a value:  4
# 4

# %% [raw]
# 3.sum of n pattern

# %%
row = 5
colums = 5

for i in range(row):
    for j in range(colums):
        print("*", end = " ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %% [markdown]
# 2.sum of numbers

# %%
num = eval(input("Entre the sum number:"))

sum = 0

for i in range(num):
    n = int(input("entre the number"))
    sum = sum + n
print("sum",sum)
# Out:
# Entre the sum number: 5
# entre the number 1
# entre the number 2
# entre the number 3
# entre the number 4
# entre the number 5
# sum 15

# %% [markdown]
# print 0 to 10 numbers

# %%
list(range(0,11,2))
# Out:
# [0, 2, 4, 6, 8, 10]

# %% [markdown]
# print odd numbers

# %%
list(range(1,11,2))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# print even numbers

# %%
for i in range(0,11,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# print odd number

# %%
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
