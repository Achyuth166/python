# %%
num = 9999

if (num > 100):
    print("Num is > 100",num)
    print("in condition")
    
print("end")
# Out:
# Num is > 100 9999
# in condition
# end

# %%
num = 10
if (num > 10):
    print("num is > 10",num)
# Out:
# end

# %% [markdown]
# ### big of 2

# %%
num1 = int(input("enetr no1"))
num2 = int(input("enter no2"))

if (num1 > num2):
    print("Num 1 is big",num1)
else:
    print("Num 2 is big",num2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 num1 = int(input("enetr no1"))
#       2 num2 = int(input("enter no2"))
#       4 if (num1 > num2):
#
# ValueError: invalid literal for int() with base 10: ''

# %% [raw]
# Note: Dont print results in loops or conditions

# %%
large = 0

if (num1 > num2):
    large =  num1
else:
    large = num2

print("Biggest num is",large)

# %% [markdown]
# ### even or odd

# %%
num = int(input("enetr number for even or odd"))

res = ''

if ( num % 2 == 0 ):
    res += "even"
else:
    res += "odd"

print("The resulr is ",res)

# %% [markdown]
# ### Num is Pos / Neg / Zero

# %%
num = eval(input("eneter a number"))

res = ''
if (num > 0):
    res = "Positive"
elif (num < 0):
    res = "Negative"
else:
    res = "Zero"
    
print(res)
# Out:
# eneter a number 100
# Positive

# %%
num = 100
if(num > 20):
    print("largest number")
# Out:
# largest number

# %%
num = -221
if(num <21):
    print("real nummber")
else:
    print("negitive number")
# Out:
# real nummber

# %% [markdown]
# 3 numbers

# %%
num1 = eval(input("entre of number1"))
num2 = eval(input("entre of number2"))
num3 = eval(input("entre of number3"))
if(num1 > num2):
            print("num1 is value")
elif(num2 < num3):
            print("num3 is value")
elif(num3 < num2):
            print("num2 is value")
else:
    print("entre value")
# Out:
# entre of number1 11
# entre of number2 12
# entre of number3 10
# num2 is value
