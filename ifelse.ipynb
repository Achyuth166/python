# %%
num = 9999

if (num > 100):
    print("Num is > 100",num)
    print("in condition")
    
print("end")
# Out:
# Num is > 100 9999
# in condition
# end

# %%
num = 66
if(num >99):
    print("num is positive",num)

# %% [markdown]
# ### big of 2

# %%
num1 = int(input("enetr no1"))
num2 = int(input("enter no2"))

if (num1 > num2):
    print("Num 1 is big",num1)
else:
    print("Num 2 is big",num2)
# Out:
# enetr no1 11
# enter no2 1.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 num1 = int(input("enetr no1"))
# ----> 2 num2 = int(input("enter no2"))
#       4 if (num1 > num2):
#       5     print("Num 1 is big",num1)
#
# ValueError: invalid literal for int() with base 10: '1.2'

# %%
num1 = eval(input("enter num1"))
num2 = eval(input("enter num2"))

if (num1 > num2):
    print("num 1 is big",num1)
else:
    print("num 2 is big",num2)

# %% [raw]
# Note: Dont print results in loops or conditions

# %%
large = 0

if (num1 > num2):
    large =  num1
else:
    large = num2

print("Biggest num is",large)

# %% [markdown]
# ### even or odd

# %%
num = int(input("enetr number for even or odd"))

res = ''

if ( num % 2 == 0 ):
    res += "even"
else:
    res += "odd"

print("The resulr is ",res)

# %% [markdown]
# ### Num is Pos / Neg / Zero

# %%
num = eval(input("eneter a number"))

res = ''
if (num > 0):
    res = "Positive"
elif (num < 0):
    res = "Negative"
else:
    res = "Zero"
    
print(res)
# Out:
# eneter a number 100
# Positive

# %%
num = eval(input("Enter the pant cost : "))

if (num >= 250 and num <= 500):
    print("pant cost is budget friendly")
elif(num >= 500 and num <= 650):
    print("pant cost is expensive")
else:
    print("see next shop")
print("end of program")
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\pandu\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     num = eval(input("Enter the pant cost : "))
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax
