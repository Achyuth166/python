# %%
products = ["Milk", "Eggs", "Bread", "Butter", "Cheese"]
prices = [2.5, 3.0, 1.5, 4.0, 5.0]
stock = [10, 20, 15, 8, 5]
def display_products():
    for i in range(len(products)):
        print(f"{products[i]} - {prices[i]} - Stock: {stock[i]}")
display_products()
# Out:
# Milk - 2.5 - Stock: 10
# Eggs - 3.0 - Stock: 20
# Bread - 1.5 - Stock: 15
# Butter - 4.0 - Stock: 8
# Cheese - 5.0 - Stock: 5

# %%
products = ["Milk", "Eggs", "Bread", "Butter", "Cheese"]
prices = [2.5, 3.0, 1.5, 4.0, 5.0]
stock = [10, 20, 15, 8, 5]


def updated_new(product_new, new_price):
    if product_new in products:
        index = products.index(product_new)
        prices[index] = new_price
        print(f"Updated {product_new} price to ${new_price}")
    else:
        print("Product not found")

updated_new("Milk", 4.55)


def updated_new(product_new,quantity):
    if product_new in products:
        index = product.index(product_new)
        stock[index] += quantity
        print(f"Updated {product_name} stock to {stock[index]}")
    else:
        print("Product not found!")
print(list(prices))


def delete_product(product_name):
    if product_name in products:
        index = products.index
# Out:
# Updated Milk price to $4.55
# [4.55, 3.0, 1.5, 4.0, 5.0]
